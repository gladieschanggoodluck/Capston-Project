# %%
import pandas as pd

# %%
meta_text = pd.read_csv('/scratch/yte9pc/InternetArchive/Datasets/Preprocessed_Data/meta_text_keywords.csv', lineterminator='\n')

# %%
meta_text
# Out:
#                                                 filePath  \
# 0      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 1      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 2      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 3      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 4      /scratch/yte9pc/InternetArchive/Datasets/longt...
# ...                                                  ...
# 59987  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59988  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59989  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59990  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59991  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
#
#                                            fileName  numPages   format  \
# 0      ddd94ef1f8a03f5c437aef75a8c968046f9adfb3.pdf      23.0  PDF 1.7
# 1      dddb3b2b97b1032cc8e62ff2557f3265dc93795a.pdf      19.0  PDF 1.4
# 2      ddde02de12982cd27961b1231f50a131b6299839.pdf       8.0  PDF 1.5
# 3      ddded15647fcbd31bad04377cea5558e6ff47ed0.pdf      14.0  PDF 1.7
# 4      dde4eec01b3c867cc6cbe641a032d94f04a29ed0.pdf       1.0  PDF 1.4
# ...                                             ...       ...      ...
# 59987  000170cb8eaabe620101ed8ece8ee8a65d57e126.pdf      40.0  PDF 1.3
# 59988  000170d20e1ceda5365ccf198ef41fb7bcf01f71.pdf       2.0  PDF 1.5
# 59989  000170d40729689c5eadb30f5722b238928eecc5.pdf       2.0  PDF 1.4
# 59990  000170d9a4dd7b249312587997c06eec29997ad6.pdf       5.0  PDF 1.6
# 59991  000170dcd8519154f8086a559c5042a19f1a084f.pdf       5.0  PDF 1.4
#
#                                                    title  \
# 0                                                    NaN
# 1             II Plan de la Calidad de las Universidades
# 2                                                    NaN
# 3                                                    NaN
# 4                                             2013_5.pdf
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                  Microsoft Word - 10-HS-05 ASI.doc
# 59990                                                NaN
# 59991  Form 990EO for DELTA COMMUNITY HOUSING PROJECT...
#
#                                 author  \
# 0                                  NaN
# 1                  Eduardo Coba Arango
# 2                       Ladányi István
# 3                             system14
# 4                                Effie
# ...                                ...
# 59987                             WIPO
# 59988                              NaN
# 59989                         jellings
# 59990                              NaN
# 59991  DELTA COMMUNITY HOUSING PROJECT
#
#                                                  subject  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                                                NaN
# 59990                                                NaN
# 59991  Net assets for period ending 12/2007 were $258...
#
#                                                  creator  \
# 0                                                    NaN
# 1                   Acrobat PDFMaker 7.0 para PowerPoint
# 2                                   Microsoft® Word 2010
# 3                                        PDF Architect 4
# 4                               PDFCreator Version 1.2.1
# ...                                                  ...
# 59987          WIPO, Free Publications, freepublications
# 59988                               DocuWorks Desk 7.2.0
# 59989                           PScript5.dll Version 5.2
# 59990                          HP Digital Sending Device
# 59991  Kofax standard Multi-Page TIFF Storage Filter ...
#
#                                          producer  height  width       size  \
# 0      Foxit Reader PDF Printer Version 7.1.0.112   843.0  596.0  1507372.0
# 1                 Acrobat Distiller 7.0 (Windows)   539.0  718.0  1161094.0
# 2                            Microsoft® Word 2010   596.0  420.0   751048.0
# 3                                 PDF Architect 4   792.0  612.0  1454200.0
# 4                            GPL Ghostscript 9.02   842.0  595.0  1503058.0
# ...                                           ...     ...    ...        ...
# 59987                              EDOCS, PUBDOCS   842.0  595.0  1503058.0
# 59988  eDocument Library version 2.5.4 PDF Filter   842.0  595.0  1503058.0
# 59989           Acrobat Distiller 8.1.0 (Windows)   792.0  612.0  1454200.0
# 59990                   HP Digital Sending Device   792.0  612.0  1454200.0
# 59991               libtiff / tiff2pdf - 20110409    72.0  576.0   124504.0
#
#        textLength                                               text  \
# 0           60643  FAKTOR-FAKTOR YANG MEMPENGARUHI PROSES PENYUSU...
# 1            6745  Universidad Católica San Antonio , Octubre de ...
# 2           16934  Ladányi, I. (2014). A Palicsi-tó mint kulturál...
# 3           47262  www.tjprc.org                                 ...
# 4            2484  640  J.V. ASIMAKOPOULOS et al CONTINUING MEDIC...
# ...           ...                                                ...
# 59987      113488  Message du directeur général Faits saillants e...
# 59988        2296  留学生奨学金 団体名  ドコモ留学生奨学金（№０３８） 応募資格  （申込書を提出す る際は...
# 59989        2833  FY 2010 COMMUNITY DEVELOPMENT PROGRAM  Staff R...
# 59990           5
# 59991         169  See a Social Security Number? Say Something! R...
#
#          language  structure  content  association
# 0      Indonesian        3.0    246.0          4.0
# 1         Spanish        1.0     63.0          1.0
# 2       Hungarian        1.0     41.0          1.0
# 3         English        1.0     41.0          1.0
# 4         English        1.0     41.0          1.0
# ...           ...        ...      ...          ...
# 59987      French        NaN      NaN          NaN
# 59988    Japanese        NaN      NaN          NaN
# 59989     English        0.0      0.0          0.0
# 59990         NaN        0.0      0.0          0.0
# 59991     English        0.0      0.0          0.0
#
# [59992 rows x 18 columns]

# %%
All_label = pd.read_csv('/scratch/yte9pc/InternetArchive/Datasets/Preprocessed_Data/Label.csv', lineterminator='\n')

# %%
All_label
# Out:
#                                                 filePath  \
# 0      /scratch/yte9pc/InternetArchive/Datasets/fatca...
# 1      /scratch/yte9pc/InternetArchive/Datasets/fatca...
# 2      /scratch/yte9pc/InternetArchive/Datasets/fatca...
# 3      /scratch/yte9pc/InternetArchive/Datasets/fatca...
# 4      /scratch/yte9pc/InternetArchive/Datasets/fatca...
# ...                                                  ...
# 59987  /scratch/yte9pc/InternetArchive/Datasets/longt...
# 59988  /scratch/yte9pc/InternetArchive/Datasets/longt...
# 59989  /scratch/yte9pc/InternetArchive/Datasets/longt...
# 59990  /scratch/yte9pc/InternetArchive/Datasets/longt...
# 59991  /scratch/yte9pc/InternetArchive/Datasets/longt...
#
#                      family  label
# 0      fatcat_longtail_lang      1
# 1      fatcat_longtail_lang      1
# 2      fatcat_longtail_lang      1
# 3      fatcat_longtail_lang      1
# 4      fatcat_longtail_lang      1
# ...                     ...    ...
# 59987    longtail_crawl_pdf      1
# 59988    longtail_crawl_pdf      1
# 59989    longtail_crawl_pdf      1
# 59990    longtail_crawl_pdf      1
# 59991    longtail_crawl_pdf      1
#
# [59992 rows x 3 columns]

# %%
df = pd.merge(meta_text, All_label)

# %%
df
# Out:
#                                                 filePath  \
# 0      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 1      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 2      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 3      /scratch/yte9pc/InternetArchive/Datasets/longt...
# 4      /scratch/yte9pc/InternetArchive/Datasets/longt...
# ...                                                  ...
# 59987  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59988  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59989  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59990  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
# 59991  /scratch/yte9pc/InternetArchive/Datasets/gwb_r...
#
#                                            fileName  numPages   format  \
# 0      ddd94ef1f8a03f5c437aef75a8c968046f9adfb3.pdf      23.0  PDF 1.7
# 1      dddb3b2b97b1032cc8e62ff2557f3265dc93795a.pdf      19.0  PDF 1.4
# 2      ddde02de12982cd27961b1231f50a131b6299839.pdf       8.0  PDF 1.5
# 3      ddded15647fcbd31bad04377cea5558e6ff47ed0.pdf      14.0  PDF 1.7
# 4      dde4eec01b3c867cc6cbe641a032d94f04a29ed0.pdf       1.0  PDF 1.4
# ...                                             ...       ...      ...
# 59987  000170cb8eaabe620101ed8ece8ee8a65d57e126.pdf      40.0  PDF 1.3
# 59988  000170d20e1ceda5365ccf198ef41fb7bcf01f71.pdf       2.0  PDF 1.5
# 59989  000170d40729689c5eadb30f5722b238928eecc5.pdf       2.0  PDF 1.4
# 59990  000170d9a4dd7b249312587997c06eec29997ad6.pdf       5.0  PDF 1.6
# 59991  000170dcd8519154f8086a559c5042a19f1a084f.pdf       5.0  PDF 1.4
#
#                                                    title  \
# 0                                                    NaN
# 1             II Plan de la Calidad de las Universidades
# 2                                                    NaN
# 3                                                    NaN
# 4                                             2013_5.pdf
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                  Microsoft Word - 10-HS-05 ASI.doc
# 59990                                                NaN
# 59991  Form 990EO for DELTA COMMUNITY HOUSING PROJECT...
#
#                                 author  \
# 0                                  NaN
# 1                  Eduardo Coba Arango
# 2                       Ladányi István
# 3                             system14
# 4                                Effie
# ...                                ...
# 59987                             WIPO
# 59988                              NaN
# 59989                         jellings
# 59990                              NaN
# 59991  DELTA COMMUNITY HOUSING PROJECT
#
#                                                  subject  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                                                NaN
# 59990                                                NaN
# 59991  Net assets for period ending 12/2007 were $258...
#
#                                                  creator  \
# 0                                                    NaN
# 1                   Acrobat PDFMaker 7.0 para PowerPoint
# 2                                   Microsoft® Word 2010
# 3                                        PDF Architect 4
# 4                               PDFCreator Version 1.2.1
# ...                                                  ...
# 59987          WIPO, Free Publications, freepublications
# 59988                               DocuWorks Desk 7.2.0
# 59989                           PScript5.dll Version 5.2
# 59990                          HP Digital Sending Device
# 59991  Kofax standard Multi-Page TIFF Storage Filter ...
#
#                                          producer  height  width       size  \
# 0      Foxit Reader PDF Printer Version 7.1.0.112   843.0  596.0  1507372.0
# 1                 Acrobat Distiller 7.0 (Windows)   539.0  718.0  1161094.0
# 2                            Microsoft® Word 2010   596.0  420.0   751048.0
# 3                                 PDF Architect 4   792.0  612.0  1454200.0
# 4                            GPL Ghostscript 9.02   842.0  595.0  1503058.0
# ...                                           ...     ...    ...        ...
# 59987                              EDOCS, PUBDOCS   842.0  595.0  1503058.0
# 59988  eDocument Library version 2.5.4 PDF Filter   842.0  595.0  1503058.0
# 59989           Acrobat Distiller 8.1.0 (Windows)   792.0  612.0  1454200.0
# 59990                   HP Digital Sending Device   792.0  612.0  1454200.0
# 59991               libtiff / tiff2pdf - 20110409    72.0  576.0   124504.0
#
#        textLength                                               text  \
# 0           60643  FAKTOR-FAKTOR YANG MEMPENGARUHI PROSES PENYUSU...
# 1            6745  Universidad Católica San Antonio , Octubre de ...
# 2           16934  Ladányi, I. (2014). A Palicsi-tó mint kulturál...
# 3           47262  www.tjprc.org                                 ...
# 4            2484  640  J.V. ASIMAKOPOULOS et al CONTINUING MEDIC...
# ...           ...                                                ...
# 59987      113488  Message du directeur général Faits saillants e...
# 59988        2296  留学生奨学金 団体名  ドコモ留学生奨学金（№０３８） 応募資格  （申込書を提出す る際は...
# 59989        2833  FY 2010 COMMUNITY DEVELOPMENT PROGRAM  Staff R...
# 59990           5
# 59991         169  See a Social Security Number? Say Something! R...
#
#          language  structure  content  association              family  label
# 0      Indonesian        3.0    246.0          4.0  longtail_crawl_pdf      1
# 1         Spanish        1.0     63.0          1.0  longtail_crawl_pdf      1
# 2       Hungarian        1.0     41.0          1.0  longtail_crawl_pdf      1
# 3         English        1.0     41.0          1.0  longtail_crawl_pdf      1
# 4         English        1.0     41.0          1.0  longtail_crawl_pdf      1
# ...           ...        ...      ...          ...                 ...    ...
# 59987      French        NaN      NaN          NaN      gwb_random_pdf      0
# 59988    Japanese        NaN      NaN          NaN      gwb_random_pdf      0
# 59989     English        0.0      0.0          0.0      gwb_random_pdf      0
# 59990         NaN        0.0      0.0          0.0      gwb_random_pdf      0
# 59991     English        0.0      0.0          0.0      gwb_random_pdf      0
#
# [59992 rows x 20 columns]

# %%
df.dtypes
# Out:
# filePath        object
# fileName        object
# numPages       float64
# format          object
# title           object
# author          object
# subject         object
# creator         object
# producer        object
# height         float64
# width          float64
# size           float64
# textLength       int64
# text            object
# language        object
# structure      float64
# content        float64
# association    float64
# family          object
# label            int64
# dtype: object

# %%
## import libraries
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import xgboost as xgb
import missingno as msno
from numpy import isnan
from sklearn.metrics import accuracy_score,make_scorer
from sklearn.model_selection import train_test_split, GridSearchCV , RandomizedSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score, classification_report,accuracy_score, confusion_matrix, roc_curve, auc, f1_score
from sklearn.impute import SimpleImputer
from numpy import nan
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.feature_selection import SelectFromModel
from sklearn import linear_model
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.inspection import permutation_importance
from sklearn.svm import SVC

sns.set() # will create pretty matplots
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
#global format settigns for plots
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#000000'
plt.rcParams['axes.labelcolor']= '#000000'
plt.rcParams['xtick.color'] = '#000000'
plt.rcParams['ytick.color'] = '#000000'
plt.rcParams['font.size']=12
warnings.filterwarnings('ignore')
pd.set_option('precision', 3) # number precision for pandas
pd.set_option('display.max_rows', 12)
pd.set_option('display.float_format', '{:20,.3f}'.format) # get rid of scientific notation
# Out:
# /apps/software/standard/compiler/gcc/9.2.0/jupyter_conda/2019.10-py3.7/lib/python3.7/site-packages/dask/dataframe/utils.py:14: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Function

# %%
##Functions used later

## identify categorical columns
# https://pbpython.com/categorical-encoding.html
def identifyCatVar(df):
    cat_df = df.select_dtypes(include = ['object']).copy()
    cat_df.head()
    return cat_df

#Function to summarize the number of rows with missing values for each column

def summarizeMissing(df):
    missing_df = []
    columns=['Variable','Missing','Percent']
    for i in range(df.shape[1]):
        # count number of rows with missing values
        n_miss = df.iloc[:,i].isnull().sum()
        perc = n_miss / df.shape[0] * 100
        values = [i,n_miss,perc]
        zipped = zip(columns, values)
        dict_miss = dict(zipped)
        missing_df.append(dict_miss)
    return missing_df
#Function to replace NAN values with mode value
def impute_nan_most_frequent_category(DataFrame,ColName):
    # .mode()[0] - gives first category name
     most_frequent_category=DataFrame[ColName].mode()[0]
    # replace nan values with most occured category
     DataFrame[ColName].fillna(most_frequent_category,inplace=True)


#https://stackoverflow.com/questions/56088264/trouble-training-xgboost-on-categorical-column
#Function to convert categories to strings so that XGBClassfier works
def catToString(X):
    df = identifyCatVar(X)
    lbl = preprocessing.LabelEncoder()
    for i in df.columns:
        X[i] = lbl.fit_transform(X[i].astype(str))
    return X

def callROC_Curve(y_pred_prob,y_train):
    # keep probabilities for the positive outcome only
    y_pred_prob = y_pred_prob[:,1]
    fpr, tpr, thresholds = roc_curve(y_train, y_pred_prob)
    best_thresh = getoptimalThreshold(fpr,tpr,thresholds,y_pred_prob,y_train)
    plt.show()
    return best_thresh

def exploreConfusionMatrix(y_pred,y_pred_prob,y,threshold):
    threshold = float(threshold)
    #y_pred = fit.predict_proba(X)
    # keep probabilities for the positive outcome only
    y_pred_prob = y_pred_prob[:,1]
    pred = [ 0 if x < threshold else 1 for x in y_pred_prob]
    print("\nConfusion Matrix for Threshold=%.3f" %threshold+"\n")
    metrics = getClassificationMetrics(y_pred,y_pred_prob,y,threshold)
    return pd.DataFrame(metrics)

# apply threshold to positive probabilities to create labels
def to_labels(pos_probs, threshold):
	return (pos_probs > threshold).astype('int')

#computes optimal threshold based on f1 score. Called from CallROC_Curve
def getoptimalThreshold(fpr, tpr,thresholds, probs,y_train):
    #the function creates a f1 score for the data using al lthe thresholds
    scores_t = [f1_score(y_train, to_labels(probs, t)) for t in thresholds]
    # get index of best threshold with max score
    ix = np.argmax(scores_t)
    print('\nBest Threshold=%.3f, F-Score=%.3f' % (thresholds[ix], scores_t[ix]))
    #sets limits for axis
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    #plot the fpr and tpr for the model
    plt.plot(fpr, tpr, marker='.', label='Model')
    #plot the best threshold point
    plt.scatter(fpr[ix], tpr[ix], marker='D', color='black', label='Best')
    #set labels and legend
    plt.xlabel('False Positive Rate (1-Specificity)')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    #return the best threshold based on the f1score
    return thresholds[ix]

#Mainly used to fill the final table of metrics exactly as asked and plot the confusion matrix(cm) where required
#takes the best estimator and any x and y values alogn with a threshold to compute the metrics and cm. used in exploreConfusionMatrix function
def getClassificationMetrics(y_pred, pred_prob, y_test,threshold):
    #compute predicted probabilities
    #pred_prob = fit.predict_proba(X)
    #keep probabilities for the positive outcome only
    #pred_prob = pred_prob[:,1]
    CM = confusion_matrix(y_test,y_pred)
    TN = CM[0][0]; FN = CM[1][0] ; TP = CM[1][1]; FP = CM[0][1]
    Population = TN+FN+TP+FP
    Accuracy   = round( ((TP+TN)*100) / Population,2)
    Accuracy = str(Accuracy)+'%'
    Recall     = round( TP / (TP+FN),4 )
    FPR        = round( FP / (TN+FP),4 )
    Specificity = 1-FPR
    FDR        = round( FP / (TP+FP),4 )
    Precision  = round( TP / (TP+FP),4 )
    auc = roc_auc_score(y_test, pred_prob)
    plt.title('Confusion Matrix')
    #get values from the confusion matrix inbuilt function and use it in a seaborn plot to make it look pretty
    sns.heatmap( pd.DataFrame(CM, columns=['Predicted Negative', 'Predicted Positive'], index=['Negative', 'Positive']), annot=True, cmap='Blues',fmt="")
    plt.show()
    #store metrics in a data frame and return. This format will eb useful to plot the final table
    metrics = pd.DataFrame({
        'Metrics':['Accuracy','AUC','Threshold','Recall','Specificity','FDR', 'Precision'],'Value':[Accuracy,auc,threshold,Recall,Specificity,FDR, Precision]})
    metrics = metrics.set_index('Metrics')
    return metrics

# %%
## return datafraome for language = English or non-English
def onlyEng(df):
    df_en = df[df['language'] == 10]
    return df_en
def nonEng(df):
    df_nonEn = df[df['language'] != 10]
    return df_nonEn

# %% [markdown]
# ## Read Dataset and Clean Dataset

# %%
## drop columns which are not considered for the features in the models
df.drop(['filePath', 'fileName', 'format', 'family'], axis = 1, inplace = True)

# %%
df
# Out:
#                   numPages                                              title  \
# 0                   23.000                                                NaN
# 1                   19.000         II Plan de la Calidad de las Universidades
# 2                    8.000                                                NaN
# 3                   14.000                                                NaN
# 4                    1.000                                         2013_5.pdf
# ...                    ...                                                ...
# 59987               40.000                                Rapport Annuel 1999
# 59988                2.000                                                NaN
# 59989                2.000                  Microsoft Word - 10-HS-05 ASI.doc
# 59990                5.000                                                NaN
# 59991                5.000  Form 990EO for DELTA COMMUNITY HOUSING PROJECT...
#
#                                 author  \
# 0                                  NaN
# 1                  Eduardo Coba Arango
# 2                       Ladányi István
# 3                             system14
# 4                                Effie
# ...                                ...
# 59987                             WIPO
# 59988                              NaN
# 59989                         jellings
# 59990                              NaN
# 59991  DELTA COMMUNITY HOUSING PROJECT
#
#                                                  subject  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                                                NaN
# 59990                                                NaN
# 59991  Net assets for period ending 12/2007 were $258...
#
#                                                  creator  \
# 0                                                    NaN
# 1                   Acrobat PDFMaker 7.0 para PowerPoint
# 2                                   Microsoft® Word 2010
# 3                                        PDF Architect 4
# 4                               PDFCreator Version 1.2.1
# ...                                                  ...
# 59987          WIPO, Free Publications, freepublications
# 59988                               DocuWorks Desk 7.2.0
# 59989                           PScript5.dll Version 5.2
# 59990                          HP Digital Sending Device
# 59991  Kofax standard Multi-Page TIFF Storage Filter ...
#
#                                          producer               height  \
# 0      Foxit Reader PDF Printer Version 7.1.0.112              843.000
# 1                 Acrobat Distiller 7.0 (Windows)              539.000
# 2                            Microsoft® Word 2010              596.000
# 3                                 PDF Architect 4              792.000
# 4                            GPL Ghostscript 9.02              842.000
# ...                                           ...                  ...
# 59987                              EDOCS, PUBDOCS              842.000
# 59988  eDocument Library version 2.5.4 PDF Filter              842.000
# 59989           Acrobat Distiller 8.1.0 (Windows)              792.000
# 59990                   HP Digital Sending Device              792.000
# 59991               libtiff / tiff2pdf - 20110409               72.000
#
#                      width                 size  textLength  \
# 0                  596.000        1,507,372.000       60643
# 1                  718.000        1,161,094.000        6745
# 2                  420.000          751,048.000       16934
# 3                  612.000        1,454,200.000       47262
# 4                  595.000        1,503,058.000        2484
# ...                    ...                  ...         ...
# 59987              595.000        1,503,058.000      113488
# 59988              595.000        1,503,058.000        2296
# 59989              612.000        1,454,200.000        2833
# 59990              612.000        1,454,200.000           5
# 59991              576.000          124,504.000         169
#
#                                                     text    language  \
# 0      FAKTOR-FAKTOR YANG MEMPENGARUHI PROSES PENYUSU...  Indonesian
# 1      Universidad Católica San Antonio , Octubre de ...     Spanish
# 2      Ladányi, I. (2014). A Palicsi-tó mint kulturál...   Hungarian
# 3      www.tjprc.org                                 ...     English
# 4      640  J.V. ASIMAKOPOULOS et al CONTINUING MEDIC...     English
# ...                                                  ...         ...
# 59987  Message du directeur général Faits saillants e...      French
# 59988  留学生奨学金 団体名  ドコモ留学生奨学金（№０３８） 応募資格  （申込書を提出す る際は...    Japanese
# 59989  FY 2010 COMMUNITY DEVELOPMENT PROGRAM  Staff R...     English
# 59990                                                            NaN
# 59991  See a Social Security Number? Say Something! R...     English
#
#                  structure              content          association  label
# 0                    3.000              246.000                4.000      1
# 1                    1.000               63.000                1.000      1
# 2                    1.000               41.000                1.000      1
# 3                    1.000               41.000                1.000      1
# 4                    1.000               41.000                1.000      1
# ...                    ...                  ...                  ...    ...
# 59987                  nan                  nan                  nan      0
# 59988                  nan                  nan                  nan      0
# 59989                0.000                0.000                0.000      0
# 59990                0.000                0.000                0.000      0
# 59991                0.000                0.000                0.000      0
#
# [59992 rows x 16 columns]

# %%
df.drop(['text'], axis=1, inplace = True)

# %%
df
# Out:
#                   numPages                                              title  \
# 0                   23.000                                                NaN
# 1                   19.000         II Plan de la Calidad de las Universidades
# 2                    8.000                                                NaN
# 3                   14.000                                                NaN
# 4                    1.000                                         2013_5.pdf
# ...                    ...                                                ...
# 59987               40.000                                Rapport Annuel 1999
# 59988                2.000                                                NaN
# 59989                2.000                  Microsoft Word - 10-HS-05 ASI.doc
# 59990                5.000                                                NaN
# 59991                5.000  Form 990EO for DELTA COMMUNITY HOUSING PROJECT...
#
#                                 author  \
# 0                                  NaN
# 1                  Eduardo Coba Arango
# 2                       Ladányi István
# 3                             system14
# 4                                Effie
# ...                                ...
# 59987                             WIPO
# 59988                              NaN
# 59989                         jellings
# 59990                              NaN
# 59991  DELTA COMMUNITY HOUSING PROJECT
#
#                                                  subject  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 59987                                Rapport Annuel 1999
# 59988                                                NaN
# 59989                                                NaN
# 59990                                                NaN
# 59991  Net assets for period ending 12/2007 were $258...
#
#                                                  creator  \
# 0                                                    NaN
# 1                   Acrobat PDFMaker 7.0 para PowerPoint
# 2                                   Microsoft® Word 2010
# 3                                        PDF Architect 4
# 4                               PDFCreator Version 1.2.1
# ...                                                  ...
# 59987          WIPO, Free Publications, freepublications
# 59988                               DocuWorks Desk 7.2.0
# 59989                           PScript5.dll Version 5.2
# 59990                          HP Digital Sending Device
# 59991  Kofax standard Multi-Page TIFF Storage Filter ...
#
#                                          producer               height  \
# 0      Foxit Reader PDF Printer Version 7.1.0.112              843.000
# 1                 Acrobat Distiller 7.0 (Windows)              539.000
# 2                            Microsoft® Word 2010              596.000
# 3                                 PDF Architect 4              792.000
# 4                            GPL Ghostscript 9.02              842.000
# ...                                           ...                  ...
# 59987                              EDOCS, PUBDOCS              842.000
# 59988  eDocument Library version 2.5.4 PDF Filter              842.000
# 59989           Acrobat Distiller 8.1.0 (Windows)              792.000
# 59990                   HP Digital Sending Device              792.000
# 59991               libtiff / tiff2pdf - 20110409               72.000
#
#                      width                 size  textLength    language  \
# 0                  596.000        1,507,372.000       60643  Indonesian
# 1                  718.000        1,161,094.000        6745     Spanish
# 2                  420.000          751,048.000       16934   Hungarian
# 3                  612.000        1,454,200.000       47262     English
# 4                  595.000        1,503,058.000        2484     English
# ...                    ...                  ...         ...         ...
# 59987              595.000        1,503,058.000      113488      French
# 59988              595.000        1,503,058.000        2296    Japanese
# 59989              612.000        1,454,200.000        2833     English
# 59990              612.000        1,454,200.000           5         NaN
# 59991              576.000          124,504.000         169     English
#
#                  structure              content          association  label
# 0                    3.000              246.000                4.000      1
# 1                    1.000               63.000                1.000      1
# 2                    1.000               41.000                1.000      1
# 3                    1.000               41.000                1.000      1
# 4                    1.000               41.000                1.000      1
# ...                    ...                  ...                  ...    ...
# 59987                  nan                  nan                  nan      0
# 59988                  nan                  nan                  nan      0
# 59989                0.000                0.000                0.000      0
# 59990                0.000                0.000                0.000      0
# 59991                0.000                0.000                0.000      0
#
# [59992 rows x 15 columns]

# %%
#print missing value summary
pd.DataFrame(summarizeMissing(df))
# Out:
#     Variable  Missing              Percent
# 0          0      705                1.175
# 1          1    25253               42.094
# 2          2    29644               49.413
# 3          3    53215               88.703
# 4          4    11229               18.717
# ..       ...      ...                  ...
# 10        10     4448                7.414
# 11        11    20878               34.801
# 12        12    20878               34.801
# 13        13    20878               34.801
# 14        14        0                0.000
#
# [15 rows x 3 columns]

# %%
# drop columns with > 80% missing values
pct_null = df.isnull().sum() / len(df)
missing_features = pct_null[pct_null > 0.80].index
df.drop(missing_features, axis=1, inplace=True)

# %%
#checkshape of new dataframe after dropping columns with > 80% missing values
print(df.shape)
pd.DataFrame(summarizeMissing(df))
# Out:
# (59992, 14)
#     Variable  Missing              Percent
# 0          0      705                1.175
# 1          1    25253               42.094
# 2          2    29644               49.413
# 3          3    11229               18.717
# 4          4     3516                5.861
# ..       ...      ...                  ...
# 9          9     4448                7.414
# 10        10    20878               34.801
# 11        11    20878               34.801
# 12        12    20878               34.801
# 13        13        0                0.000
#
# [14 rows x 3 columns]

# %% [markdown]
# ## Impute missing categorical values

# %%
#create a copy of the dataframe to impute dategorical columns missing values
cat_impute_df = identifyCatVar(df)
#Call function to impute with most occured category
for Columns in cat_impute_df.columns.to_list():
    impute_nan_most_frequent_category(cat_impute_df,Columns)

# %%
#drop the categorical columsn to impute numericalvalues
num_impute_df= df.drop(columns=cat_impute_df.columns.to_list())

# %% [markdown]
# ## Impute missing numerical vvalues

# %%
#another imputing technicque based on mean, median, most_frequent 
#all vlaues give same results. therefore going with most_frequent
imputer_s = SimpleImputer(missing_values=nan, strategy='most_frequent')
# transform the dataset
impute_data = pd.DataFrame(imputer_s.fit_transform(num_impute_df))
# count the number of NaN values in each column
pd.DataFrame(summarizeMissing(impute_data))
# Out:
#    Variable  Missing              Percent
# 0         0        0                0.000
# 1         1        0                0.000
# 2         2        0                0.000
# 3         3        0                0.000
# 4         4        0                0.000
# 5         5        0                0.000
# 6         6        0                0.000
# 7         7        0                0.000
# 8         8        0                0.000

# %% [markdown]
# ## Merge back final imputed dataset

# %%
#create new dataframe with imputed data and combine with categorical variables to create final imputed dataset
impute_data.columns = num_impute_df.columns
final_data = pd.concat([impute_data,cat_impute_df],axis=1)
final_data.shape
# Out:
# (59992, 14)

# %%
#make sure final_dataset looks good
final_data.head(5)
# Out:
#               numPages               height                width  \
# 0               23.000              843.000              596.000
# 1               19.000              539.000              718.000
# 2                8.000              596.000              420.000
# 3               14.000              792.000              612.000
# 4                1.000              842.000              595.000
#
#                   size           textLength            structure  \
# 0        1,507,372.000           60,643.000                3.000
# 1        1,161,094.000            6,745.000                1.000
# 2          751,048.000           16,934.000                1.000
# 3        1,454,200.000           47,262.000                1.000
# 4        1,503,058.000            2,484.000                1.000
#
#                content          association                label  \
# 0              246.000                4.000                1.000
# 1               63.000                1.000                1.000
# 2               41.000                1.000                1.000
# 3               41.000                1.000                1.000
# 4               41.000                1.000                1.000
#
#                                         title               author  \
# 0                                    untitled        Administrator
# 1  II Plan de la Calidad de las Universidades  Eduardo Coba Arango
# 2                                    untitled       Ladányi István
# 3                                    untitled             system14
# 4                                  2013_5.pdf                Effie
#
#                                 creator  \
# 0            PScript5.dll Version 5.2.2
# 1  Acrobat PDFMaker 7.0 para PowerPoint
# 2                  Microsoft® Word 2010
# 3                       PDF Architect 4
# 4              PDFCreator Version 1.2.1
#
#                                      producer    language
# 0  Foxit Reader PDF Printer Version 7.1.0.112  Indonesian
# 1             Acrobat Distiller 7.0 (Windows)     Spanish
# 2                        Microsoft® Word 2010   Hungarian
# 3                             PDF Architect 4     English
# 4                        GPL Ghostscript 9.02     English

# %% [markdown]
# ## Create dependent and undependent variables to run classificaiton with train and test data

# %%
## Checking proportion of data
fig, ax = plt.subplots(1, 2)
plt.figure(figsize = (4, 4))
sns.countplot('label', data= final_data, ax=ax[0])
final_data['label'].value_counts().plot.pie(explode=[0, 0.2], autopct='%1.2f%%', ax=ax[1])
fig.show()

# %%
# create X nad Y from final dataset
final_data = catToString(final_data,)

#create X and Y
X = final_data.drop(final_data[['label']],axis=1)
Y = final_data[['label']]
#create train and test set to check accuracy, using stratify as the data is imbalanced
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70,stratify=Y,random_state=1)

# %% [markdown]
# ## Bayes

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Training the Naive Bayes model on the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Training the Naive Bayes model on the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)

# %%
ac
# Out:
# 0.7436937437493055

# %%
cm
# Out:
# array([[8699,  299],
#        [4314, 4686]])

# %% [markdown]
# ## Logistic Regression to compare with XGBoost

# %%
## Logistic Regression with cross validation
# we must apply the scaling to the test set that we computed for the training set
clf_lr = linear_model.LogisticRegressionCV(cv=5, random_state=1).fit(X_train, y_train)
y_pred = clf_lr.predict(X_test)
print('Accuracy of logistic regression classifier on test set: %.2f%%' %(clf_lr.score(X_test, y_test)*100))
# Out:
# Accuracy of logistic regression classifier on test set: 81.06%

# %% [markdown]
# ## SVM to compare with XGBoost

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train.values.ravel())
# make predictions for test data and evaluate
svm_pred = svm_model.predict(X_test)
accuracy_svm = accuracy_score(y_test, svm_pred)
print("\n\nAccuracy with 11 features: %.2f%%" % (accuracy_svm* 100.0))
# Out:
# Accuracy with 11 features: 90.40%

# %% [markdown]
# ## XGBoost

# %%
# fit model on all the training data and check accuracy
model_fs = xgb.XGBClassifier(verbosity=0)
model_fs.fit(X_train, y_train);
# make predictions for test data and evaluate
pred_fs = model_fs.predict(X_test)
accuracy = accuracy_score(y_test, pred_fs)
print("\n\nAccuracy with 11 features: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy with 11 features: 95.35%

# %%
#create a subset of data removing thsoe features with importance 0
sorted_idx = model_fs.feature_importances_.argsort()
feature_imp = pd.DataFrame(X.columns[sorted_idx], model_fs.feature_importances_[sorted_idx])
feature_imp = feature_imp.reset_index()
feature_imp.columns=['importance','features']
reduced_data = final_data[feature_imp[feature_imp["importance"] > 0].features.values.tolist()]

# %%
#Top 11 features
feature_imp= feature_imp.set_index('features')
feature_imp.tail(10).plot.barh(title='Top 10 Features');

# %%
# change categorical variables to strings in the reduced dataset
reduced_data = catToString(reduced_data)

# %%
#create new training and test data with reduced data and check accuracy
X_train_rd, X_test_rd, y_train, y_test = train_test_split(reduced_data, Y, train_size = 0.70, stratify = Y, random_state = 1)
model_rd = xgb.XGBClassifier(verbosity = 0)
model_rd.fit(X_train_rd, y_train)
#make predictions for test data and evaluate
pred_rd = model_rd.predict(X_test_rd)
accuracy_rd = accuracy_score(y_test, pred_rd)
print("\n\nAccuracy with selected selected features: %.2f%%" % (accuracy_rd * 100.0))
# Out:
# Accuracy with selected selected features: 95.35%

# %% [markdown]
# ## Hyper parameter tuning for XGBoost

# %%
# performing on 3 splits in interest of time
kfold = StratifiedKFold(n_splits=3, random_state=1,shuffle=True)
# Create a pipeline
pipe = Pipeline([
('scaler', StandardScaler()),
  ('clf', xgb.XGBClassifier(objective='binary:logistic',verbosity=0))
])
search_space = [
  {
    'clf__n_estimators': [150,200],
    'clf__learning_rate': [0.01, 0.1, 0.2, 0.3],
    'clf__max_depth': range(3, 10),
    'clf__colsample_bytree': [i/10.0 for i in range(1, 3)],
    'clf__gamma': [i/10.0 for i in range(3)]
  }
]
# AUC and accuracy as score
scoring = {'AUC':'roc_auc', 'Accuracy':make_scorer(accuracy_score)}
# Define grid search
grid = GridSearchCV(
  pipe,
  param_grid=search_space,
  cv=kfold,
  scoring=scoring,
  refit='AUC'
)
# Fit grid search
model = grid.fit(X_train_rd, y_train)

# %% [markdown]
# ## ROC and AUC based on model

# %%
#predict using the best model
#focusing on accuracy and default threshold
print('Best Params: ', model.best_params_)
##ROC Curve
#find best threshold to use on test dataset
#finding threshold on training data takes a long time
predict = model.predict(X_test_rd)
y_pred_tr = model.predict_proba(X_train_rd)
thresh = callROC_Curve(y_pred_tr,y_train)
#use threshold now on test set to get metrics
y_pred_prob_test = model.predict_proba(X_test_rd)
exploreConfusionMatrix(predict, y_pred_prob_test,y_test,thresh)
# Out:
# Best Params:  {'clf__colsample_bytree': 0.2, 'clf__gamma': 0.1, 'clf__learning_rate': 0.3, 'clf__max_depth': 8, 'clf__n_estimators': 200}
#
# Best Threshold=0.420, F-Score=0.893
# Confusion Matrix for Threshold=0.420
#                            Value
# Metrics
# Accuracy                  77.67%
# AUC                        0.864
# Threshold                  0.420
# Recall                     0.714
# Specificity                0.840
# FDR                        0.183
# Precision                  0.817

# %% [markdown]
# ## ROC and AUC based on non-grid search model

# %%
#predict using the best model
#focusing on accuracy and default threshold
# print('Best Params: ', model_rd.best_params_)
##ROC Curve
#find best threshold to use on test dataset
#finding threshold on training data takes a long time
predict = model_rd.predict(X_test_rd)
y_pred_tr = model_rd.predict_proba(X_train_rd)
thresh = callROC_Curve(y_pred_tr,y_train)
#use threshold now on test set to get metrics
y_pred_prob_test = model_rd.predict_proba(X_test_rd)
exploreConfusionMatrix(predict, y_pred_prob_test,y_test,thresh)
# Out:
# Best Threshold=0.478, F-Score=0.970
# Confusion Matrix for Threshold=0.478
#                            Value
# Metrics
# Accuracy                  95.35%
# AUC                        0.992
# Threshold                  0.478
# Recall                     0.949
# Specificity                0.958
# FDR                        0.043
# Precision                  0.957

# %% [markdown]
# ## Keras

# %%
# neural network with keras
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
import keras
import keras.utils
from keras import utils as np_utils
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import tensorflow as tf
from tensorflow import keras

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.70,stratify=Y,random_state=1)

# %%
X_train
# Out:
#                   numPages               height                width  \
# 8868                 2.000              794.000              596.000
# 1269                 5.000              828.000              609.000
# 20978                4.000              791.000              596.000
# 37389                3.000              792.000              612.000
# 56652               24.000              792.000              612.000
# ...                    ...                  ...                  ...
# 1184                11.000              792.000              612.000
# 50662               13.000              842.000              596.000
# 51122               10.000              842.000              596.000
# 14414                1.000              792.000              612.000
# 51415                1.000              842.000              596.000
#
#                       size           textLength            structure  \
# 8868         1,419,760.000            5,113.000                0.000
# 1269         1,512,844.000           27,561.000                1.000
# 20978        1,414,396.000           12,063.000                2.000
# 37389        1,454,200.000            7,438.000                0.000
# 56652        1,454,200.000          114,148.000                1.000
# ...                    ...                  ...                  ...
# 1184         1,454,200.000           51,836.000                1.000
# 50662        1,505,584.000           23,423.000                0.000
# 51122        1,505,584.000           26,823.000                1.000
# 14414        1,454,200.000              715.000                0.000
# 51415        1,505,584.000            4,400.000                0.000
#
#                    content          association  title  author  subject  \
# 8868                 0.000                0.000  28901     746     1706
# 1269                41.000                1.000   9330     520     1706
# 20978               20.000               16.000  28901     746     1706
# 37389                0.000                0.000  28901    7486     1706
# 56652                9.000               21.000   9012   16011     1706
# ...                    ...                  ...    ...     ...      ...
# 1184                41.000                1.000  28901    1520     1706
# 50662                0.000                0.000  28901    5957     1706
# 51122               25.000               48.000  28901   16378     1706
# 14414                0.000                0.000  15809     737     1706
# 51415                0.000                0.000  28901     746     1706
#
#        creator  producer  language
# 8868      1250       243        10
# 1269      3418       312        10
# 20978     1265       176        10
# 37389      774       968        10
# 56652     3418       309        10
# ...        ...       ...       ...
# 1184      3016      2046        10
# 50662     3137      2136        19
# 51122     3026      2060        10
# 14414     3418      1569        10
# 51415     2050       223        28
#
# [41994 rows x 14 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

model = Sequential()

model.add(Dense(2048, activation='relu', input_shape=(14,)))
model.add(Dense(1024, activation='relu', ))
opt = keras.optimizers.Adam(learning_rate = 0.001)

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= opt,
              metrics=['accuracy'])
                   
model.fit(X_train, y_train,epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# 41994/41994 [==============================] - 185s 4ms/step - loss: 0.2975 - accuracy: 0.8799
# Epoch 2/50
# 41994/41994 [==============================] - 187s 4ms/step - loss: 0.2507 - accuracy: 0.8995
# Epoch 3/50
# 41994/41994 [==============================] - 187s 4ms/step - loss: 0.2393 - accuracy: 0.9054
# Epoch 4/50
# 41994/41994 [==============================] - 185s 4ms/step - loss: 0.2350 - accuracy: 0.9084
# Epoch 5/50
# 41994/41994 [==============================] - 186s 4ms/step - loss: 0.2361 - accuracy: 0.9120
# Epoch 6/50
# 41994/41994 [==============================] - 188s 4ms/step - loss: 0.2324 - accuracy: 0.9124
# Epoch 7/50
# 41994/41994 [==============================] - 192s 5ms/step - loss: 0.2256 - accuracy: 0.9139
# Epoch 8/50
# 41994/41994 [==============================] - 193s 5ms/step - loss: 0.2392 - accuracy: 0.9149
# Epoch 9/50
# 41994/41994 [==============================] - 196s 5ms/step - loss: 0.2225 - accuracy: 0.9169
# Epoch 10/50
# 41994/41994 [==============================] - 196s 5ms/step - loss: 0.2448 - accuracy: 0.9168
# Epoch 11/50
# 41994/41994 [==============================] - 194s 5ms/step - loss: 0.2233 - accuracy: 0.9175
# Epoch 12/50
# 41994/41994 [==============================] - 194s 5ms/step - loss: 0.2279 - accuracy: 0.9166
# Epoch 13/50
# 41994/41994 [==============================] - 193s 5ms/step - loss: 0.2210 - accuracy: 0.9200
# Epoch 14/50
# 41994/41994 [==============================] - 197s 5ms/step - loss: 0.2423 - accuracy: 0.9203
# Epoch 15/50
# 41994/41994 [==============================] - 198s 5ms/step - loss: 0.2181 - accuracy: 0.9195
# Epoch 16/50
# 41994/41994 [==============================] - 202s 5ms/step - loss: 0.2217 - accuracy: 0.9208
# Epoch 17/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2375 - accuracy: 0.9197
# Epoch 18/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2484 - accuracy: 0.9203
# Epoch 19/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2294 - accuracy: 0.9205
# Epoch 20/50
# 41994/41994 [==============================] - 201s 5ms/step - loss: 0.2195 - accuracy: 0.9208
# Epoch 21/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2283 - accuracy: 0.9213
# Epoch 22/50
# 41994/41994 [==============================] - 204s 5ms/step - loss: 0.2215 - accuracy: 0.9214
# Epoch 23/50
# 41994/41994 [==============================] - 204s 5ms/step - loss: 0.2138 - accuracy: 0.9221
# Epoch 24/50
# 41994/41994 [==============================] - 209s 5ms/step - loss: 0.2738 - accuracy: 0.9215
# Epoch 25/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2274 - accuracy: 0.9214
# Epoch 26/50
# 41994/41994 [==============================] - 202s 5ms/step - loss: 0.2692 - accuracy: 0.9236
# Epoch 27/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2303 - accuracy: 0.9212
# Epoch 28/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.3262 - accuracy: 0.9217
# Epoch 29/50
# 41994/41994 [==============================] - 207s 5ms/step - loss: 0.2540 - accuracy: 0.9232
# Epoch 30/50
# 41994/41994 [==============================] - 209s 5ms/step - loss: 0.2404 - accuracy: 0.9223
# Epoch 31/50
# 41994/41994 [==============================] - 206s 5ms/step - loss: 0.2431 - accuracy: 0.9235
# Epoch 32/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2212 - accuracy: 0.9230
# Epoch 33/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2446 - accuracy: 0.9234
# Epoch 34/50
# 41994/41994 [==============================] - 206s 5ms/step - loss: 0.2440 - accuracy: 0.9229
# Epoch 35/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2778 - accuracy: 0.9228
# Epoch 36/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2487 - accuracy: 0.9224
# Epoch 37/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2274 - accuracy: 0.9233
# Epoch 38/50
# 41994/41994 [==============================] - 207s 5ms/step - loss: 0.2581 - accuracy: 0.9236
# Epoch 39/50
# 41994/41994 [==============================] - 207s 5ms/step - loss: 0.2433 - accuracy: 0.9251
# Epoch 40/50
# 41994/41994 [==============================] - 204s 5ms/step - loss: 0.3024 - accuracy: 0.9254
# Epoch 41/50
# 41994/41994 [==============================] - 207s 5ms/step - loss: 0.2215 - accuracy: 0.9247
# Epoch 42/50
# 41994/41994 [==============================] - 204s 5ms/step - loss: 0.7122 - accuracy: 0.9260
# Epoch 43/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2254 - accuracy: 0.9267
# Epoch 44/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2683 - accuracy: 0.9204
# Epoch 45/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2700 - accuracy: 0.9232
# Epoch 46/50
# 41994/41994 [==============================] - 203s 5ms/step - loss: 0.2202 - accuracy: 0.9239
# Epoch 47/50
# 41994/41994 [==============================] - 206s 5ms/step - loss: 0.4283 - accuracy: 0.9242
# Epoch 48/50
# 41994/41994 [==============================] - 207s 5ms/step - loss: 0.2337 - accuracy: 0.9262
# Epoch 49/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.3194 - accuracy: 0.9261
# Epoch 50/50
# 41994/41994 [==============================] - 205s 5ms/step - loss: 0.2306 - accuracy: 0.9268

# %%
model.compile(loss='binary_crossentropy',
              optimizer= opt,
              metrics=['accuracy'])
                   
model.fit(X_train, y_train,epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 41994/41994 [==============================] - 134s 3ms/step - loss: 0.2999 - accuracy: 0.8801
# Epoch 2/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2595 - accuracy: 0.9017
# Epoch 3/100
# 41994/41994 [==============================] - 134s 3ms/step - loss: 0.2555 - accuracy: 0.9067
# Epoch 4/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2280 - accuracy: 0.9106
# Epoch 5/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2373 - accuracy: 0.9122
# Epoch 6/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2296 - accuracy: 0.9145
# Epoch 7/100
# 41994/41994 [==============================] - 134s 3ms/step - loss: 0.2235 - accuracy: 0.9170
# Epoch 8/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2201 - accuracy: 0.9168
# Epoch 9/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2264 - accuracy: 0.9164
# Epoch 10/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2205 - accuracy: 0.9180
# Epoch 11/100
# 41994/41994 [==============================] - 134s 3ms/step - loss: 0.2438 - accuracy: 0.9188
# Epoch 12/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2179 - accuracy: 0.9188
# Epoch 13/100
# 41994/41994 [==============================] - 136s 3ms/step - loss: 0.2111 - accuracy: 0.9199
# Epoch 14/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2254 - accuracy: 0.9219
# Epoch 15/100
# 41994/41994 [==============================] - 135s 3ms/step - loss: 0.2224 - accuracy: 0.9219
# Epoch 16/100
# 41994/41994 [==============================] - 139s 3ms/step - loss: 0.2148 - accuracy: 0.9209
# Epoch 17/100
# 41994/41994 [==============================] - 146s 3ms/step - loss: 0.2402 - accuracy: 0.9218
# Epoch 18/100
# 41994/41994 [==============================] - 146s 3ms/step - loss: 0.2273 - accuracy: 0.9228
# Epoch 19/100
# 41994/41994 [==============================] - 146s 3ms/step - loss: 0.2217 - accuracy: 0.9245
# Epoch 20/100
# 41994/41994 [==============================] - 145s 3ms/step - loss: 0.2391 - accuracy: 0.9248
# Epoch 21/100
# 41994/41994 [==============================] - 146s 3ms/step - loss: 0.2482 - accuracy: 0.9236
# Epoch 22/100
# 41994/41994 [==============================] - 145s 3ms/step - loss: 0.2100 - accuracy: 0.9256
# Epoch 23/100
# 41994/41994 [==============================] - 143s 3ms/step - loss: 0.2315 - accuracy: 0.9262
# Epoch 24/100
# 41994/41994 [==============================] - 144s 3ms/step - loss: 0.2359 - accuracy: 0.9261
# Epoch 25/100
# 41994/41994 [==============================] - 144s 3ms/step - loss: 0.2006 - accuracy: 0.9261
# Epoch 26/100
# 41994/41994 [==============================] - 144s 3ms/step - loss: 0.2132 - accuracy: 0.9259
# Epoch 27/100
# 41994/41994 [==============================] - 144s 3ms/step - loss: 0.2034 - accuracy: 0.9264
# Epoch 28/100
# 41994/41994 [==============================] - 144s 3ms/step - loss: 0.2033 - accuracy: 0.9277
# Epoch 29/100
# 41994/41994 [==============================] - 148s 4ms/step - loss: 0.1948 - accuracy: 0.9284
# Epoch 30/100
# 41994/41994 [==============================] - 148s 4ms/step - loss: 0.2280 - accuracy: 0.9278
# Epoch 31/100
# 41994/41994 [==============================] - 151s 4ms/step - loss: 0.2149 - accuracy: 0.9288
# Epoch 32/100
# 41994/41994 [==============================] - 150s 4ms/step - loss: 0.2023 - accuracy: 0.9273
# Epoch 33/100
# 41994/41994 [==============================] - 152s 4ms/step - loss: 0.2271 - accuracy: 0.9285
# Epoch 34/100
# 41994/41994 [==============================] - 152s 4ms/step - loss: 0.1917 - accuracy: 0.9294
# Epoch 35/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2221 - accuracy: 0.9303
# Epoch 36/100
# 41994/41994 [==============================] - 147s 4ms/step - loss: 0.2140 - accuracy: 0.9295
# Epoch 37/100
# 41994/41994 [==============================] - 148s 4ms/step - loss: 0.2483 - accuracy: 0.9289
# Epoch 38/100
# 41994/41994 [==============================] - 147s 3ms/step - loss: 0.1914 - accuracy: 0.9276
# Epoch 39/100
# 41994/41994 [==============================] - 150s 4ms/step - loss: 0.2043 - accuracy: 0.9298
# Epoch 40/100
# 41994/41994 [==============================] - 148s 4ms/step - loss: 0.2038 - accuracy: 0.9299
# Epoch 41/100
# 41994/41994 [==============================] - 151s 4ms/step - loss: 0.2091 - accuracy: 0.9304
# Epoch 42/100
# 41994/41994 [==============================] - 154s 4ms/step - loss: 0.2116 - accuracy: 0.9302
# Epoch 43/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2661 - accuracy: 0.9307
# Epoch 44/100
# 41994/41994 [==============================] - 154s 4ms/step - loss: 0.2847 - accuracy: 0.9298
# Epoch 45/100
# 41994/41994 [==============================] - 153s 4ms/step - loss: 0.1929 - accuracy: 0.9318
# Epoch 46/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2163 - accuracy: 0.9316
# Epoch 47/100
# 41994/41994 [==============================] - 156s 4ms/step - loss: 0.2295 - accuracy: 0.9317
# Epoch 48/100
# 41994/41994 [==============================] - 156s 4ms/step - loss: 0.1851 - accuracy: 0.9321
# Epoch 49/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2170 - accuracy: 0.9323
# Epoch 50/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2182 - accuracy: 0.9318
# Epoch 51/100
# 41994/41994 [==============================] - 155s 4ms/step - loss: 0.2151 - accuracy: 0.9322
# Epoch 52/100
# 41994/41994 [==============================] - 165s 4ms/step - loss: 0.2300 - accuracy: 0.9324
# Epoch 53/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.2853 - accuracy: 0.9326
# Epoch 54/100
# 41994/41994 [==============================] - 163s 4ms/step - loss: 0.1906 - accuracy: 0.9320
# Epoch 55/100
# 41994/41994 [==============================] - 167s 4ms/step - loss: 0.1992 - accuracy: 0.9321
# Epoch 56/100
# 41994/41994 [==============================] - 166s 4ms/step - loss: 0.2927 - accuracy: 0.9335
# Epoch 57/100
# 41994/41994 [==============================] - 163s 4ms/step - loss: 0.2651 - accuracy: 0.9337
# Epoch 58/100
# 41994/41994 [==============================] - 162s 4ms/step - loss: 0.2795 - accuracy: 0.9342
# Epoch 59/100
# 41994/41994 [==============================] - 161s 4ms/step - loss: 0.2540 - accuracy: 0.9342
# Epoch 60/100
# 41994/41994 [==============================] - 163s 4ms/step - loss: 0.3033 - accuracy: 0.9343
# Epoch 61/100
# 41994/41994 [==============================] - 160s 4ms/step - loss: 0.1859 - accuracy: 0.9339
# Epoch 62/100
# 41994/41994 [==============================] - 148s 4ms/step - loss: 0.2695 - accuracy: 0.9343
# Epoch 63/100
# 41994/41994 [==============================] - 149s 4ms/step - loss: 0.1976 - accuracy: 0.9354
# Epoch 64/100
# 41994/41994 [==============================] - 149s 4ms/step - loss: 0.2410 - accuracy: 0.9356
# Epoch 65/100
# 41994/41994 [==============================] - 157s 4ms/step - loss: 0.2748 - accuracy: 0.9354
# Epoch 66/100
# 41994/41994 [==============================] - 159s 4ms/step - loss: 0.2333 - accuracy: 0.9350
# Epoch 67/100
# 41994/41994 [==============================] - 158s 4ms/step - loss: 0.2382 - accuracy: 0.9360
# Epoch 68/100
# 41994/41994 [==============================] - 159s 4ms/step - loss: 0.2627 - accuracy: 0.9355
# Epoch 69/100
# 41994/41994 [==============================] - 160s 4ms/step - loss: 0.2299 - accuracy: 0.9353
# Epoch 70/100
# 41994/41994 [==============================] - 160s 4ms/step - loss: 0.1992 - accuracy: 0.9356
# Epoch 71/100
# 41994/41994 [==============================] - 160s 4ms/step - loss: 0.2382 - accuracy: 0.9358
# Epoch 72/100
# 41994/41994 [==============================] - 158s 4ms/step - loss: 0.3117 - accuracy: 0.9359
# Epoch 73/100
# 41994/41994 [==============================] - 164s 4ms/step - loss: 0.2009 - accuracy: 0.9353
# Epoch 74/100
# 41994/41994 [==============================] - 173s 4ms/step - loss: 0.2510 - accuracy: 0.9356
# Epoch 75/100
# 41994/41994 [==============================] - 170s 4ms/step - loss: 0.2096 - accuracy: 0.9362
# Epoch 76/100
# 41994/41994 [==============================] - 171s 4ms/step - loss: 0.2015 - accuracy: 0.9359
# Epoch 77/100
# 41994/41994 [==============================] - 169s 4ms/step - loss: 0.1903 - accuracy: 0.9360
# Epoch 78/100
# 41994/41994 [==============================] - 171s 4ms/step - loss: 0.2135 - accuracy: 0.9356
# Epoch 79/100
# 41994/41994 [==============================] - 173s 4ms/step - loss: 0.2873 - accuracy: 0.9356
# Epoch 80/100
# 41994/41994 [==============================] - 175s 4ms/step - loss: 0.2989 - accuracy: 0.9352
# Epoch 81/100
# 41994/41994 [==============================] - 173s 4ms/step - loss: 0.1792 - accuracy: 0.9362
# Epoch 82/100
# 41994/41994 [==============================] - 171s 4ms/step - loss: 0.1851 - accuracy: 0.9368
# Epoch 83/100
# 41994/41994 [==============================] - 170s 4ms/step - loss: 0.1814 - accuracy: 0.9373
# Epoch 84/100
# 41994/41994 [==============================] - 167s 4ms/step - loss: 0.2198 - accuracy: 0.9363
# Epoch 85/100
# 41994/41994 [==============================] - 169s 4ms/step - loss: 0.2628 - accuracy: 0.9366
# Epoch 86/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.2430 - accuracy: 0.9371
# Epoch 87/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.3210 - accuracy: 0.9363
# Epoch 88/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.1816 - accuracy: 0.9367
# Epoch 89/100
# 41994/41994 [==============================] - 170s 4ms/step - loss: 0.2345 - accuracy: 0.9362
# Epoch 90/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.1873 - accuracy: 0.9367
# Epoch 91/100
# 41994/41994 [==============================] - 168s 4ms/step - loss: 0.2435 - accuracy: 0.9367
# Epoch 92/100
# 41994/41994 [==============================] - 170s 4ms/step - loss: 0.3206 - accuracy: 0.9373
# Epoch 93/100
# 41994/41994 [==============================] - 169s 4ms/step - loss: 0.2495 - accuracy: 0.9371
# Epoch 94/100
# 41994/41994 [==============================] - 167s 4ms/step - loss: 0.2976 - accuracy: 0.9367
# Epoch 95/100
# 41994/41994 [==============================] - 166s 4ms/step - loss: 0.3050 - accuracy: 0.9371
# Epoch 96/100
# 20694/41994 [=============>................] - ETA: 1:24 - loss: 0.1743 - accuracy: 0.9389

# %% [markdown]
# ## Language = English

# %%
final_data_eng = onlyEng(final_data)

# %%
final_data_noneng = nonEng(final_data)

# %% [markdown]
# ## Bayesian Model Averaging

# %%
df = final_data
df['label_y'] = df['label']
# Out:
#                   numPages               height                width  \
# 0                   24.000              842.000              596.000
# 1                   23.000            1,313.000              862.000
# 2                    7.000              842.000              596.000
# 3                    5.000              794.000              595.000
# 4                   11.000            1,319.000              919.000
# ...                    ...                  ...                  ...
# 59987               42.000              841.000              594.000
# 59988                4.000              842.000              596.000
# 59989                1.000              792.000              612.000
# 59990                1.000              792.000              612.000
# 59991                2.000              842.000              596.000
#
#                       size           textLength                label  title  \
# 0            1,505,584.000           51,491.000                1.000  28901
# 1            3,395,506.000               23.000                1.000  28901
# 2            1,505,584.000           26,528.000                1.000  28901
# 3            1,417,378.000           13,244.000                1.000   3514
# 4            3,636,571.000               11.000                1.000  28901
# ...                    ...                  ...                  ...    ...
# 59987        1,498,750.000          114,613.000                1.000  23345
# 59988        1,505,584.000           19,168.000                1.000   1739
# 59989        1,454,200.000            6,393.000                1.000  28901
# 59990        1,454,200.000            2,014.000                1.000   6965
# 59991        1,505,584.000            2,241.000                1.000   3402
#
#        author  creator  producer  language              label_y
# 0         746     3418      2352        43                1.000
# 1         746      864       723        10                1.000
# 2         746     1100       919        29                1.000
# 3       19442     3418       495        10                1.000
# 4         746      864       723        10                1.000
# ...       ...      ...       ...       ...                  ...
# 59987    8843      599       169        10                1.000
# 59988   19827     1127       349        37                1.000
# 59989     746     2000      3669        10                1.000
# 59990    8172      646       934        10                1.000
# 59991     746     2384      2980        31                1.000
#
# [59992 rows x 12 columns]

# %%
df
# Out:
#                   numPages               height                width  \
# 0                    0.228                0.202               -0.118
# 1                    0.209                3.017                1.620
# 2                   -0.086                0.202               -0.118
# 3                   -0.123               -0.085               -0.124
# 4                   -0.012                3.053                1.992
# ...                    ...                  ...                  ...
# 59987                0.560                0.196               -0.131
# 59988               -0.141                0.202               -0.118
# 59989               -0.197               -0.097               -0.013
# 59990               -0.197               -0.097               -0.013
# 59991               -0.178                0.202               -0.118
#
#                       size           textLength                title  \
# 0                   -0.019                0.290                0.796
# 1                    1.140               -0.323                0.796
# 2                   -0.019               -0.007                0.796
# 3                   -0.073               -0.165               -1.891
# 4                    1.288               -0.323                0.796
# ...                    ...                  ...                  ...
# 59987               -0.023                1.042                0.208
# 59988               -0.019               -0.095               -2.079
# 59989               -0.051               -0.247                0.796
# 59990               -0.051               -0.299               -1.526
# 59991               -0.019               -0.296               -1.903
#
#                     author              creator  producer  language  \
# 0                   -0.735                0.614      2352        43
# 1                   -0.735               -1.541       723        10
# 2                   -0.735               -1.342       919        29
# 3                    1.982                0.614       495        10
# 4                   -0.735               -1.541       723        10
# ...                    ...                  ...       ...       ...
# 59987                0.442               -1.765       169        10
# 59988                2.038               -1.319       349        37
# 59989               -0.735               -0.582      3669        10
# 59990                0.344               -1.725       934        10
# 59991               -0.735               -0.258      2980        31
#
#                    label_y
# 0                    1.000
# 1                    1.000
# 2                    1.000
# 3                    1.000
# 4                    1.000
# ...                    ...
# 59987                1.000
# 59988                1.000
# 59989                1.000
# 59990                1.000
# 59991                1.000
#
# [59992 rows x 11 columns]

# %%
## normalization
# Standardize the data (mean for each numerical variable of zero, standard deviation of one.)
for key in df.keys()[0:9]:
    try:
        print("Standardizing "+key+".")
        df[key] = df[key] - np.mean(df[key])
        df[key] = df[key] / np.std(df[key])
    except:
        print("Predictor "+key+" cannot be standardized (probably a categorical variable).")
df.describe()
# Out:
# Standardizing numPages.
# Standardizing height.
# Standardizing width.
# Standardizing size.
# Standardizing textLength.
# Standardizing title.
# Standardizing author.
# Standardizing creator.
# Standardizing producer.
#                   numPages               height                width  \
# count           59,992.000           59,992.000           59,992.000
# mean                -0.000                0.000                0.000
# std                  1.000                1.000                1.000
# min                 -0.197               -4.562               -3.717
# 25%                 -0.178               -0.097               -0.124
# 50%                 -0.123               -0.085               -0.118
# 75%                 -0.012                0.202               -0.013
# max                184.310               56.009               45.218
#
#                       size           textLength                title  \
# count           59,992.000           59,992.000           59,992.000
# mean                 0.000               -0.000                0.000
# std                  1.000                1.000                1.000
# min                 -0.939               -0.323               -2.263
# 25%                 -0.051               -0.291               -0.808
# 50%                 -0.032               -0.174                0.673
# 75%                 -0.019                0.038                0.796
# max                140.224               99.854                0.927
#
#                     author              creator             producer  \
# count           59,992.000           59,992.000           59,992.000
# mean                -0.000               -0.000               -0.000
# std                  1.000                1.000                1.000
# min                 -0.844               -2.270               -1.302
# 25%                 -0.735               -0.917               -0.940
# 50%                 -0.735                0.364               -0.401
# 75%                  0.762                0.614                0.556
# max                  2.321                2.029                2.452
#
#                   language              label_y
# count           59,992.000           59,992.000
# mean                15.017                0.500
# std                  9.396                0.500
# min                  0.000                0.000
# 25%                 10.000                0.000
# 50%                 10.000                1.000
# 75%                 19.000                1.000
# max                 47.000                1.000

# %%
import numpy as np 
import pandas as pd 
import statsmodels.api as sm
from statsmodels.tools import add_constant
from itertools import combinations
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
import pandas as pd
import numpy as np
import pprint
import PyPDF2
import pdfminer
import pymc3 as pm
import os
import glob
import random
from langdetect import detect
from langdetect import detect_langs

# %%
X = df[["numPages", "height", "width", "size", "textLength", "title", "author", "creator", "producer", "language"]]
y = df["label_y"]
# building the model and fitting the data 
log_reg = sm.Logit(y, add_constant(X)).fit()
log_reg.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.675967
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                label_y   No. Observations:                59992
# Model:                          Logit   Df Residuals:                    59981
# Method:                           MLE   Df Model:                           10
# Date:                Thu, 04 Mar 2021   Pseudo R-squ.:                 0.02479
# Time:                        12:35:02   Log-Likelihood:                -40553.
# converged:                       True   LL-Null:                       -41583.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0598      0.016     -3.817      0.000      -0.091      -0.029
# numPages      -0.0500      0.015     -3.229      0.001      -0.080      -0.020
# height         0.0237      0.016      1.455      0.146      -0.008       0.056
# width         -0.2417      0.017    -14.195      0.000      -0.275      -0.208
# size           0.0983      0.030      3.303      0.001       0.040       0.157
# textLength     0.0185      0.009      2.047      0.041       0.001       0.036
# title         -0.0237      0.009     -2.708      0.007      -0.041      -0.007
# author        -0.2691      0.009    -30.106      0.000      -0.287      -0.252
# creator        0.0345      0.009      3.963      0.000       0.017       0.052
# producer      -0.2630      0.009    -29.723      0.000      -0.280      -0.246
# language       0.0038      0.001      4.302      0.000       0.002       0.006
# ==============================================================================
# """

# %%
## BMA 
from mpmath import mp
mp.dps = 50
class BMA:
    
    def __init__(self, y, X, **kwargs):
        # Setup the basic variables.
        self.y = y
        self.X = X
        self.names = list(X.columns)
        self.nRows, self.nCols = np.shape(X)
        self.likelihoods = mp.zeros(self.nCols,1)
        self.likelihoods_all = {}
        self.coefficients_mp = mp.zeros(self.nCols,1)
        self.coefficients = np.zeros(self.nCols)
        self.probabilities = np.zeros(self.nCols)
        # Check the max model size. (Max number of predictor variables to use in a model.)
        # This can be used to reduce the runtime but not doing an exhaustive sampling.
        if 'MaxVars' in kwargs.keys():
            self.MaxVars = kwargs['MaxVars']
        else:
            self.MaxVars = self.nCols  
        # Prepare the priors if they are provided.
        # The priors are provided for the individual regressor variables.
        # The prior for a model is the product of the priors on the variables in the model.
        if 'Priors' in kwargs.keys():
            if np.size(kwargs['Priors']) == self.nCols:
                self.Priors = kwargs['Priors']
            else:
                print("WARNING: Provided priors error.  Using equal priors instead.")
                print("The priors should be a numpy array of length equal tot he number of regressor variables.")
                self.Priors = np.ones(self.nCols)  
        else:
            self.Priors = np.ones(self.nCols)  
        if 'Verbose' in kwargs.keys():
            self.Verbose = kwargs['Verbose'] 
        else:
            self.Verbose = False 
        if 'RegType' in kwargs.keys():
            self.RegType = kwargs['RegType'] 
        else:
            self.RegType = 'LS' 
        
    def fit(self):
        # Perform the Bayesian Model Averaging
        
        # Initialize the sum of the likelihoods for all the models to zero.  
        # This will be the 'normalization' denominator in Bayes Theorem.
        likelighood_sum = 0
        
        # To facilitate iterating through all possible models, we start by iterating thorugh
        # the number of elements in the model.  
        max_likelihood = 0
        for num_elements in range(1,self.MaxVars+1): 
            
            if self.Verbose == True:
                print("Computing BMA for models of size: ", num_elements)
            
            # Make a list of all index sets of models of this size.
            Models_next = list(combinations(list(range(self.nCols)), num_elements)) 
             
            # Occam's window - compute the candidate models to use for the next iteration
            # Models_previous: the set of models from the previous iteration that satisfy (likelihhod > max_likelihhod/20)
            # Models_next:     the set of candidate models for the next iteration
            # Models_current:  the set of models from Models_next that can be consturcted by adding one new variable
            #                    to a model from Models_previous
            if num_elements == 1:
                Models_current = Models_next
                Models_previous = []
            else:
                idx_keep = np.zeros(len(Models_next))
                for M_new,idx in zip(Models_next,range(len(Models_next))):
                    for M_good in Models_previous:
                        if(all(x in M_new for x in M_good)):
                            idx_keep[idx] = 1
                            break
                        else:
                            pass
                Models_current = np.asarray(Models_next)[np.where(idx_keep==1)].tolist()
                Models_previous = []
                        
            
            # Iterate through all possible models of the given size.
            for model_index_set in Models_current:
                
                # Compute the linear regression for this given model. 
                model_X = self.X.iloc[:,list(model_index_set)]
                if self.RegType == 'Logit':
                    model_regr = sm.Logit(self.y, model_X).fit(disp=0)
                else:
                    model_regr = OLS(self.y, model_X).fit()
                
                # Compute the likelihood (times the prior) for the model. 
                model_likelihood = mp.exp(-model_regr.bic/2)*np.prod(self.Priors[list(model_index_set)])
                    
                if (model_likelihood > max_likelihood/20):
                    if self.Verbose == True:
                        print("Model Variables:",model_index_set,"likelihood=",model_likelihood)
                    self.likelihoods_all[str(model_index_set)] = model_likelihood
                    
                    # Add this likelihood to the running tally of likelihoods.
                    likelighood_sum = mp.fadd(likelighood_sum, model_likelihood)

                    # Add this likelihood (times the priors) to the running tally
                    # of likelihoods for each variable in the model.
                    for idx, i in zip(model_index_set, range(num_elements)):
                        self.likelihoods[idx] = mp.fadd(self.likelihoods[idx], model_likelihood, prec=1000)
                        self.coefficients_mp[idx] = mp.fadd(self.coefficients_mp[idx], model_regr.params[i]*model_likelihood, prec=1000)
                    Models_previous.append(model_index_set) # add this model to the list of good models
                    max_likelihood = np.max([max_likelihood,model_likelihood]) # get the new max likelihood if it is this model
                else:
                    if self.Verbose == True:
                        print("Model Variables:",model_index_set,"rejected by Occam's window")
                    

        # Divide by the denominator in Bayes theorem to normalize the probabilities 
        # sum to one.
        self.likelighood_sum = likelighood_sum
        for idx in range(self.nCols):
            self.probabilities[idx] = mp.fdiv(self.likelihoods[idx],likelighood_sum, prec=1000)
            self.coefficients[idx] = mp.fdiv(self.coefficients_mp[idx],likelighood_sum, prec=1000)
        
        # Return the new BMA object as an output.
        return self
    
    def predict(self, data):
        data = np.asarray(data)
        if self.RegType == 'Logit':
            try:
                result = 1/(1+np.exp(-1*np.dot(self.coefficients,data)))
            except:
                result = 1/(1+np.exp(-1*np.dot(self.coefficients,data.T)))
        else:
            try:
                result = np.dot(self.coefficients,data)
            except:
                result = np.dot(self.coefficients,data.T)
        
        return result  
        
    def summary(self):
        # Return the BMA results as a data frame for easy viewing.
        df = pd.DataFrame([self.names, list(self.probabilities), list(self.coefficients)], 
             ["Variable Name", "Probability", "Avg. Coefficient"]).T
        return df

# %%
X = df[["numPages", "height", "width", "size", "textLength", "title", "author", "creator", "producer", "language"]]
y = df["label_y"]
result = BMA(y ,add_constant(X), RegType = 'Logit', Verbose=True).fit()
# Out:
# Computing BMA for models of size:  1
# Model Variables: (0,) likelihood= 1.6583840446569224964741639152433998315897620824819e-18062
# Model Variables: (1,) likelihood= 1.43103602603428792241288446952123618003595595549e-18060
# Model Variables: (2,) likelihood= 2.2808336053010143658232221741951044205123773574975e-18057
# Model Variables: (3,) likelihood= 1.4202382777698400412835429688948810601058572059239e-17995
# Model Variables: (4,) rejected by Occam's window
# Model Variables: (5,) rejected by Occam's window
# Model Variables: (6,) rejected by Occam's window
# Model Variables: (7,) likelihood= 6.6786082402320269959501041930835080054664193241053e-17904
# Model Variables: (8,) rejected by Occam's window
# Model Variables: (9,) rejected by Occam's window
# Model Variables: (10,) rejected by Occam's window
# Computing BMA for models of size:  2
# Model Variables: [0, 1] rejected by Occam's window
# Model Variables: [0, 2] rejected by Occam's window
# Model Variables: [0, 3] rejected by Occam's window
# Model Variables: [0, 4] rejected by Occam's window
# Model Variables: [0, 5] rejected by Occam's window
# Model Variables: [0, 6] rejected by Occam's window
# Model Variables: [0, 7] rejected by Occam's window
# Model Variables: [0, 8] rejected by Occam's window
# Model Variables: [0, 9] rejected by Occam's window
# Model Variables: [0, 10] rejected by Occam's window
# Model Variables: [1, 2] rejected by Occam's window
# Model Variables: [1, 3] rejected by Occam's window
# Model Variables: [1, 4] rejected by Occam's window
# Model Variables: [1, 5] rejected by Occam's window
# Model Variables: [1, 6] rejected by Occam's window
# Model Variables: [1, 7] likelihood= 8.4048387323835395300953391195178918323444212070609e-17905
# Model Variables: [1, 8] rejected by Occam's window
# Model Variables: [1, 9] rejected by Occam's window
# Model Variables: [1, 10] rejected by Occam's window
# Model Variables: [2, 3] rejected by Occam's window
# Model Variables: [2, 4] rejected by Occam's window
# Model Variables: [2, 5] rejected by Occam's window
# Model Variables: [2, 6] rejected by Occam's window
# Model Variables: [2, 7] likelihood= 2.0363704727056306793027330559135021709939671159928e-17899
# Model Variables: [2, 8] rejected by Occam's window
# Model Variables: [2, 9] rejected by Occam's window
# Model Variables: [2, 10] rejected by Occam's window
# Model Variables: [3, 4] rejected by Occam's window
# Model Variables: [3, 5] rejected by Occam's window
# Model Variables: [3, 6] rejected by Occam's window
# Model Variables: [3, 7] likelihood= 1.3457964878615415503966579414333990201193330492333e-17841
# Model Variables: [3, 8] rejected by Occam's window
# Model Variables: [3, 9] rejected by Occam's window
# Model Variables: [3, 10] rejected by Occam's window
# Model Variables: [4, 7] rejected by Occam's window
# Model Variables: [5, 7] rejected by Occam's window
# Model Variables: [6, 7] rejected by Occam's window
# Model Variables: [7, 8] rejected by Occam's window
# Model Variables: [7, 9] likelihood= 2.5769142858694385331495461122623911403334737118983e-17705
# Model Variables: [7, 10] rejected by Occam's window
# Computing BMA for models of size:  3
# Model Variables: [0, 1, 7] rejected by Occam's window
# Model Variables: [0, 2, 7] rejected by Occam's window
# Model Variables: [0, 3, 7] rejected by Occam's window
# Model Variables: [0, 7, 9] rejected by Occam's window
# Model Variables: [1, 2, 7] rejected by Occam's window
# Model Variables: [1, 3, 7] rejected by Occam's window
# Model Variables: [1, 4, 7] rejected by Occam's window
# Model Variables: [1, 5, 7] rejected by Occam's window
# Model Variables: [1, 6, 7] rejected by Occam's window
# Model Variables: [1, 7, 8] rejected by Occam's window
# Model Variables: [1, 7, 9] likelihood= 2.9923852179105145727179761070246083958025151755494e-17706
# Model Variables: [1, 7, 10] rejected by Occam's window
# Model Variables: [2, 3, 7] rejected by Occam's window
# Model Variables: [2, 4, 7] rejected by Occam's window
# Model Variables: [2, 5, 7] rejected by Occam's window
# Model Variables: [2, 6, 7] rejected by Occam's window
# Model Variables: [2, 7, 8] rejected by Occam's window
# Model Variables: [2, 7, 9] likelihood= 7.0421014786015967489597121878044279979599532603298e-17702
# Model Variables: [2, 7, 10] rejected by Occam's window
# Model Variables: [3, 4, 7] rejected by Occam's window
# Model Variables: [3, 5, 7] rejected by Occam's window
# Model Variables: [3, 6, 7] rejected by Occam's window
# Model Variables: [3, 7, 8] rejected by Occam's window
# Model Variables: [3, 7, 9] likelihood= 1.9994037619428383936154529578038801488530964383588e-17643
# Model Variables: [3, 7, 10] rejected by Occam's window
# Model Variables: [4, 7, 9] rejected by Occam's window
# Model Variables: [5, 7, 9] rejected by Occam's window
# Model Variables: [6, 7, 9] rejected by Occam's window
# Model Variables: [7, 8, 9] rejected by Occam's window
# Model Variables: [7, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  4
# Model Variables: [0, 1, 7, 9] rejected by Occam's window
# Model Variables: [0, 2, 7, 9] rejected by Occam's window
# Model Variables: [0, 3, 7, 9] rejected by Occam's window
# Model Variables: [1, 2, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 7, 9] likelihood= 1.6297354429694271452306768452989343391084153794976e-17643
# Model Variables: [1, 4, 7, 9] rejected by Occam's window
# Model Variables: [1, 5, 7, 9] rejected by Occam's window
# Model Variables: [1, 6, 7, 9] rejected by Occam's window
# Model Variables: [1, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 7, 9, 10] rejected by Occam's window
# Model Variables: [2, 3, 7, 9] likelihood= 4.1717690660147545761237209429251722358243638302222e-17638
# Model Variables: [2, 4, 7, 9] rejected by Occam's window
# Model Variables: [2, 5, 7, 9] rejected by Occam's window
# Model Variables: [2, 6, 7, 9] rejected by Occam's window
# Model Variables: [2, 7, 8, 9] rejected by Occam's window
# Model Variables: [2, 7, 9, 10] rejected by Occam's window
# Model Variables: [3, 4, 7, 9] likelihood= 4.9206004165952689884349613748480676544728201535846e-17635
# Model Variables: [3, 5, 7, 9] rejected by Occam's window
# Model Variables: [3, 6, 7, 9] rejected by Occam's window
# Model Variables: [3, 7, 8, 9] rejected by Occam's window
# Model Variables: [3, 7, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  5
# Model Variables: [0, 1, 3, 7, 9] rejected by Occam's window
# Model Variables: [0, 2, 3, 7, 9] rejected by Occam's window
# Model Variables: [0, 3, 4, 7, 9] rejected by Occam's window
# Model Variables: [1, 2, 3, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 7, 9] likelihood= 3.9049390953919381203496115820076373331627334342431e-17635
# Model Variables: [1, 3, 5, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 6, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 3, 7, 9, 10] rejected by Occam's window
# Model Variables: [2, 3, 4, 7, 9] rejected by Occam's window
# Model Variables: [2, 3, 5, 7, 9] rejected by Occam's window
# Model Variables: [2, 3, 6, 7, 9] rejected by Occam's window
# Model Variables: [2, 3, 7, 8, 9] rejected by Occam's window
# Model Variables: [2, 3, 7, 9, 10] rejected by Occam's window
# Model Variables: [3, 4, 5, 7, 9] rejected by Occam's window
# Model Variables: [3, 4, 6, 7, 9] likelihood= 6.726798682539511443257229734874317767348228727548e-17636
# Model Variables: [3, 4, 7, 8, 9] likelihood= 1.1046024603125820189689452784848318405902695682731e-17633
# Model Variables: [3, 4, 7, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  6
# Model Variables: [0, 1, 3, 4, 7, 9] rejected by Occam's window
# Model Variables: [0, 3, 4, 6, 7, 9] rejected by Occam's window
# Model Variables: [0, 3, 4, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 2, 3, 4, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 5, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 6, 7, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 7, 8, 9] likelihood= 5.8147269136758244117952643820262297839936577537459e-17634
# Model Variables: [1, 3, 4, 7, 9, 10] rejected by Occam's window
# Model Variables: [2, 3, 4, 6, 7, 9] rejected by Occam's window
# Model Variables: [2, 3, 4, 7, 8, 9] rejected by Occam's window
# Model Variables: [3, 4, 5, 6, 7, 9] rejected by Occam's window
# Model Variables: [3, 4, 5, 7, 8, 9] rejected by Occam's window
# Model Variables: [3, 4, 6, 7, 8, 9] likelihood= 1.5867413076404926675541366535757233911917499133481e-17634
# Model Variables: [3, 4, 6, 7, 9, 10] rejected by Occam's window
# Model Variables: [3, 4, 7, 8, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  7
# Model Variables: [0, 1, 3, 4, 7, 8, 9] rejected by Occam's window
# Model Variables: [0, 3, 4, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 2, 3, 4, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 5, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 6, 7, 8, 9] likelihood= 7.8043389607566280432925728107395942119102734850494e-17635
# Model Variables: [1, 3, 4, 7, 8, 9, 10] rejected by Occam's window
# Model Variables: [2, 3, 4, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [3, 4, 5, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [3, 4, 6, 7, 8, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  8
# Model Variables: [0, 1, 3, 4, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 2, 3, 4, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 5, 6, 7, 8, 9] rejected by Occam's window
# Model Variables: [1, 3, 4, 6, 7, 8, 9, 10] rejected by Occam's window
# Computing BMA for models of size:  9
# Computing BMA for models of size:  10
# Computing BMA for models of size:  11

# %%
result.summary()
# Out:
#    Variable Name          Probability     Avg. Coefficient
# 0          const                0.000                0.000
# 1       numPages                0.346               -0.015
# 2         height                0.000                0.000
# 3          width                1.000               -0.248
# 4           size                1.000                0.130
# 5     textLength                0.000                0.000
# 6          title                0.121               -0.003
# 7         author                1.000               -0.264
# 8        creator                0.953                0.034
# 9       producer                1.000               -0.265
# 10      language                0.000                0.000

# %%
def plot_traces(traces, retain=0):
    '''
    Convenience function:
    Plot traces with overlaid means and values
    '''

    ax = pm.traceplot(traces[-retain:],
                      lines=tuple([(k, {}, v['mean'])
                                   for k, v in pm.summary(traces[-retain:]).iterrows()]))

    for i, mn in enumerate(pm.summary(traces[-retain:])['mean']):
        ax[i,0].annotate('{:.2f}'.format(mn), xy=(mn,0), xycoords='data'
                    ,xytext=(5,10), textcoords='offset points', rotation=90
                    ,va='bottom', fontsize='large', color='#AA0022')

# %%
X = df[["numPages", "height", "width", "size", "textLength", "title", "author", "creator", "producer", "language"]]
y = df["label_y"]
result = BMA(y ,add_constant(X), RegType = 'Logit', Verbose=True).fit()

# %%
## advi method
with pm.Model() as model:
    pm.glm.GLM.from_formula('df.label_y~ df.numPages + df.height + df.width + df.textLength + df.title + df.author + df.producer + df.language',
                            df,
                            family=pm.glm.families.Binomial())

    #trace = pm.sample(5000)
    approx = pm.fit(5000, method = 'advi')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5000' class='' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5000/5000 00:38<00:00 Average Loss = inf]
#     </div>
# Finished [100%]: Average Loss = 1.0706e+05

# %% [markdown]
# ## Pycaret

# %% [markdown]
# ## import Dataset

# %%
data_k = final_data.drop(['label'], axis=1, inplace=True)

# %%
data_k = final_data

# %% [markdown]
# ## Setting up Environment

# %%
from pycaret.clustering import *
clu1 = setup(data_k, normalize = True, session_id = 123)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            17:14:21
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#             Data Type
# numPages      Numeric
# height        Numeric
# width         Numeric
# size          Numeric
# textLength    Numeric
# structure     Numeric
# content       Numeric
# association   Numeric
# title         Numeric
# author        Numeric
# creator       Numeric
# producer      Numeric
# language      Numeric

# %% [markdown]
# ## Create a Model

# %%
kmeans = create_model('kmeans')

# %% [markdown]
# ## Analyze ModeL

# %%
plot_model(kmeans)
